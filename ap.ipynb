# %%
import pandas as pd
import numpy as np
from pyecharts import options as opts
from pyecharts.charts import Bar ,Calendar,Tab
from pathlib import Path

# %%
df=pd.read_excel("test.xlsx", sheet_name="ap")

# %%
print(df.head(10))
# Out:
#                  Date        NAME AREA  UNITS  PICKS Shift Column1  Column2  \
# USER
# ASHLEY     2022-04-14      Ashley   B3   3924    427   NaN     NaN      NaN
# BAWANY     2022-04-14      BAWANY   A1    641    221   NaN     NaN      NaN
# BSUMANGIL  2022-04-14   Benedicta   B3   2507    541   NaN     NaN      NaN
# DALDRIN    2022-04-14      Doucot   AA   3721    470   NaN     NaN      NaN
# Doucot     2022-04-14      Aldrin   B3   1332     18   NaN     NaN      NaN
# DALWINDER1 2022-04-14   Dalwinder   B3   4605    798   NaN     NaN      NaN
# DGRANT     2022-04-14       Diana   A1    120     36   NaN     NaN      NaN
# EDHILAN    2022-04-14      Dhilan   A1    586    147   NaN     NaN      NaN
# Dhilan     2022-04-14  Jayasinghe   B3    243     50   NaN     NaN      NaN
# ERAGUKUMAR 2022-04-14   Ragukumar   AA   3405    551   NaN     NaN      NaN
#
#             Month
# USER
# ASHLEY          4
# BAWANY          4
# BSUMANGIL       4
# DALDRIN         4
# Doucot          4
# DALWINDER1      4
# DGRANT          4
# EDHILAN         4
# Dhilan          4
# ERAGUKUMAR      4

# %%
s = df[['USER','PICKS']]
print(s)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16156\2770859598.py in <module>
# ----> 1 s = df[['USER','PICKS']]
#       2 print(s)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5859             raise KeyError(f"{not_found} not in index")
#    5860
#    5861     @overload
#
# KeyError: "['USER'] not in index"

# %%
pivoted = df.pivot_table(index="USER", columns="AREA", values="PICKS",aggfunc= 'sum',margins = True, margins_name='Total')
pivoted
df1=pivoted.tail(10).fillna('0').astype(int)
print(df1)
# Out:
# AREA             A1      AA      B3     G1    Total
# USER
# TUSHY          5592       0    5325      0    10917
# Tushyanthii       0       0    1241      0     1241
# USANTHAN          0       0     218      0      218
# VBERBER01         0       0       0      1        1
# VIMALA            0       0   69422      0    69422
# Vijaya          581       0    2216      0     2797
# WINKLETTE      4041       0    5577      0     9618
# YSUYEN            0       2    1797      0     1799
# riley             0       0       1      0        1
# Total        112478  121836  813090  55104  1102508

# %%
s.loc[(s['PICKS'] > 920) & (s['AREA'] =='B3') ,s.style.applymap()] = 'GREEN' 
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16156\4229121574.py in <module>
# ----> 1 s.loc[(s['PICKS'] > 920) & (s['AREA'] =='B3') ,s.style.applymap()] = 'GREEN'
#       2 print(s)
#
# TypeError: applymap() missing 1 required positional argument: 'func'

# %%
def bg_colour_col (col):
    colour = 'red'
    return ['background-color: %s' % colour 
                if col.name=='PICKS'   # color column `Total` or row `4`
                else ''
             for i,x in col.iteritems()]

s.style.apply(bg_colour_col)
# Out:
# <style type="text/css">
# #T_b4136_row0_col1, #T_b4136_row1_col1, #T_b4136_row2_col1, #T_b4136_row3_col1, #T_b4136_row4_col1, #T_b4136_row5_col1, #T_b4136_row6_col1, #T_b4136_row7_col1, #T_b4136_row8_col1, #T_b4136_row9_col1, #T_b4136_row10_col1, #T_b4136_row11_col1, #T_b4136_row12_col1, #T_b4136_row13_col1, #T_b4136_row14_col1, #T_b4136_row15_col1, #T_b4136_row16_col1, #T_b4136_row17_col1, #T_b4136_row18_col1, #T_b4136_row19_col1, #T_b4136_row20_col1, #T_b4136_row21_col1, #T_b4136_row22_col1, #T_b4136_row23_col1, #T_b4136_row24_col1, #T_b4136_row25_col1, #T_b4136_row26_col1, #T_b4136_row27_col1, #T_b4136_row28_col1, #T_b4136_row29_col1, #T_b4136_row30_col1, #T_b4136_row31_col1, #T_b4136_row32_col1, #T_b4136_row33_col1, #T_b4136_row34_col1, #T_b4136_row35_col1, #T_b4136_row36_col1, #T_b4136_row37_col1, #T_b4136_row38_col1, #T_b4136_row39_col1, #T_b4136_row40_col1, #T_b4136_row41_col1, #T_b4136_row42_col1, #T_b4136_row43_col1, #T_b4136_row44_col1, #T_b4136_row45_col1, #T_b4136_row46_col1, #T_b4136_row47_col1, #T_b4136_row48_col1, #T_b4136_row49_col1, #T_b4136_row50_col1, #T_b4136_row51_col1, #T_b4136_row52_col1, #T_b4136_row53_col1, #T_b4136_row54_col1, #T_b4136_row55_col1, #T_b4136_row56_col1, #T_b4136_row57_col1, #T_b4136_row58_col1, #T_b4136_row59_col1, #T_b4136_row60_col1, #T_b4136_row61_col1, #T_b4136_row62_col1, #T_b4136_row63_col1, #T_b4136_row64_col1, #T_b4136_row65_col1, #T_b4136_row66_col1, #T_b4136_row67_col1, #T_b4136_row68_col1, #T_b4136_row69_col1, #T_b4136_row70_col1, #T_b4136_row71_col1, #T_b4136_row72_col1, #T_b4136_row73_col1, #T_b4136_row74_col1, #T_b4136_row75_col1, #T_b4136_row76_col1, #T_b4136_row77_col1, #T_b4136_row78_col1, #T_b4136_row79_col1, #T_b4136_row80_col1, #T_b4136_row81_col1, #T_b4136_row82_col1, #T_b4136_row83_col1, #T_b4136_row84_col1, #T_b4136_row85_col1, #T_b4136_row86_col1, #T_b4136_row87_col1, #T_b4136_row88_col1, #T_b4136_row89_col1, #T_b4136_row90_col1, #T_b4136_row91_col1, #T_b4136_row92_col1, #T_b4136_row93_col1, #T_b4136_row94_col1, #T_b4136_row95_col1, #T_b4136_row96_col1, #T_b4136_row97_col1, #T_b4136_row98_col1, #T_b4136_row99_col1, #T_b4136_row100_col1, #T_b4136_row101_col1, #T_b4136_row102_col1, #T_b4136_row103_col1, #T_b4136_row104_col1, #T_b4136_row105_col1, #T_b4136_row106_col1, #T_b4136_row107_col1, #T_b4136_row108_col1, #T_b4136_row109_col1, #T_b4136_row110_col1, #T_b4136_row111_col1, #T_b4136_row112_col1, #T_b4136_row113_col1, #T_b4136_row114_col1, #T_b4136_row115_col1, #T_b4136_row116_col1, #T_b4136_row117_col1, #T_b4136_row118_col1, #T_b4136_row119_col1, #T_b4136_row120_col1, #T_b4136_row121_col1, #T_b4136_row122_col1, #T_b4136_row123_col1, #T_b4136_row124_col1, #T_b4136_row125_col1, #T_b4136_row126_col1, #T_b4136_row127_col1, #T_b4136_row128_col1, #T_b4136_row129_col1, #T_b4136_row130_col1, #T_b4136_row131_col1, #T_b4136_row132_col1, #T_b4136_row133_col1, #T_b4136_row134_col1, #T_b4136_row135_col1, #T_b4136_row136_col1, #T_b4136_row137_col1, #T_b4136_row138_col1, #T_b4136_row139_col1, #T_b4136_row140_col1, #T_b4136_row141_col1, #T_b4136_row142_col1, #T_b4136_row143_col1, #T_b4136_row144_col1, #T_b4136_row145_col1, #T_b4136_row146_col1, #T_b4136_row147_col1, #T_b4136_row148_col1, #T_b4136_row149_col1, #T_b4136_row150_col1, #T_b4136_row151_col1, #T_b4136_row152_col1, #T_b4136_row153_col1, #T_b4136_row154_col1, #T_b4136_row155_col1, #T_b4136_row156_col1, #T_b4136_row157_col1, #T_b4136_row158_col1, #T_b4136_row159_col1, #T_b4136_row160_col1, #T_b4136_row161_col1, #T_b4136_row162_col1, #T_b4136_row163_col1, #T_b4136_row164_col1, #T_b4136_row165_col1, #T_b4136_row166_col1, #T_b4136_row167_col1, #T_b4136_row168_col1, #T_b4136_row169_col1, #T_b4136_row170_col1, #T_b4136_row171_col1, #T_b4136_row172_col1, #T_b4136_row173_col1, #T_b4136_row174_col1, #T_b4136_row175_col1, #T_b4136_row176_col1, #T_b4136_row177_col1, #T_b4136_row178_col1, #T_b4136_row179_col1, #T_b4136_row180_col1, #T_b4136_row181_col1, #T_b4136_row182_col1, #T_b4136_row183_col1, #T_b4136_row184_col1, #T_b4136_row185_col1, #T_b4136_row186_co ...

# %%
def even_number_background(cell_value):

    top = 'background-color: red;'
    mid = 'background-color: green;'
    low = 'background-color: yellow;'
    default = ''

    if type(cell_value) in [float, int,str]:
        if (cell_value =='RED')  :
            return top
        if (cell_value =='GREEN')  :
            return mid
        if (cell_value =='YELLOW')  :
            return low
    return default



s.style.applymap(even_number_background)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dd449">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd449_level0_col0" class="col_heading level0 col0" >USER</th>
#       <th id="T_dd449_level0_col1" class="col_heading level0 col1" >PICKS</th>
#       <th id="T_dd449_level0_col2" class="col_heading level0 col2" >AREA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd449_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd449_row0_col0" class="data row0 col0" >ASHLEY</td>
#       <td id="T_dd449_row0_col1" class="data row0 col1" >427</td>
#       <td id="T_dd449_row0_col2" class="data row0 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd449_row1_col0" class="data row1 col0" >BAWANY</td>
#       <td id="T_dd449_row1_col1" class="data row1 col1" >221</td>
#       <td id="T_dd449_row1_col2" class="data row1 col2" >A1</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd449_row2_col0" class="data row2 col0" >BSUMANGIL</td>
#       <td id="T_dd449_row2_col1" class="data row2 col1" >541</td>
#       <td id="T_dd449_row2_col2" class="data row2 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd449_row3_col0" class="data row3 col0" >DALDRIN</td>
#       <td id="T_dd449_row3_col1" class="data row3 col1" >470</td>
#       <td id="T_dd449_row3_col2" class="data row3 col2" >AA</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dd449_row4_col0" class="data row4 col0" >Doucot</td>
#       <td id="T_dd449_row4_col1" class="data row4 col1" >18</td>
#       <td id="T_dd449_row4_col2" class="data row4 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dd449_row5_col0" class="data row5 col0" >DALWINDER1</td>
#       <td id="T_dd449_row5_col1" class="data row5 col1" >798</td>
#       <td id="T_dd449_row5_col2" class="data row5 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dd449_row6_col0" class="data row6 col0" >DGRANT</td>
#       <td id="T_dd449_row6_col1" class="data row6 col1" >36</td>
#       <td id="T_dd449_row6_col2" class="data row6 col2" >A1</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dd449_row7_col0" class="data row7 col0" >EDHILAN</td>
#       <td id="T_dd449_row7_col1" class="data row7 col1" >147</td>
#       <td id="T_dd449_row7_col2" class="data row7 col2" >A1</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dd449_row8_col0" class="data row8 col0" >Dhilan</td>
#       <td id="T_dd449_row8_col1" class="data row8 col1" >50</td>
#       <td id="T_dd449_row8_col2" class="data row8 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dd449_row9_col0" class="data row9 col0" >ERAGUKUMAR</td>
#       <td id="T_dd449_row9_col1" class="data row9 col1" >551</td>
#       <td id="T_dd449_row9_col2" class="data row9 col2" >AA</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dd449_row10_col0" class="data row10 col0" >ESIVA</td>
#       <td id="T_dd449_row10_col1" class="data row10 col1" >104</td>
#       <td id="T_dd449_row10_col2" class="data row10 col2" >A1</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dd449_row11_col0" class="data row11 col0" >ESTHERWM</td>
#       <td id="T_dd449_row11_col1" class="data row11 col1" >271</td>
#       <td id="T_dd449_row11_col2" class="data row11 col2" >A1</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dd449_row12_col0" class="data row12 col0" >GEMMA</td>
#       <td id="T_dd449_row12_col1" class="data row12 col1" >454</td>
#       <td id="T_dd449_row12_col2" class="data row12 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dd449_row13_col0" class="data row13 col0" >GPETRIE</td>
#       <td id="T_dd449_row13_col1" class="data row13 col1" >335</td>
#       <td id="T_dd449_row13_col2" class="data row13 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dd449_row14_col0" class="data row14 col0" >HGIDDEN</td>
#       <td id="T_dd449_row14_col1" class="data row14 col1" >232</td>
#       <td id="T_dd449_row14_col2" class="data row14 col2" >G1</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dd449_row15_col0" class="data row15 col0" >JPAUL</td>
#       <td id="T_dd449_row15_col1" class="data row15 col1" >600</td>
#       <td id="T_dd449_row15_col2" class="data row15 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dd449_row16_col0" class="data row16 col0" >KUMARI</td>
#       <td id="T_dd449_row16_col1" class="data row16 col1" >508</td>
#       <td id="T_dd449_row16_col2" class="data row16 col2" >A1</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dd449_row17_col0" class="data row17 col0" >LUCINA01</td>
#       <td id="T_dd449_row17_col1" class="data row17 col1" >563</td>
#       <td id="T_dd449_row17_col2" class="data row17 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dd449_row18_col0" class="data row18 col0" >MALATHY01</td>
#       <td id="T_dd449_row18_col1" class="data row18 col1" >1009</td>
#       <td id="T_dd449_row18_col2" class="data row18 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_dd449_row19_col0" class="data row19 col0" >MATHALYP</td>
#       <td id="T_dd449_row19_col1" class="data row19 col1" >428</td>
#       <td id="T_dd449_row19_col2" class="data row19 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_dd449_row20_col0" class="data row20 col0" >MCHARLES</td>
#       <td id="T_dd449_row20_col1" class="data row20 col1" >452</td>
#       <td id="T_dd449_row20_col2" class="data row20 col2" >G1</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_dd449_row21_col0" class="data row21 col0" >MMADDEN</td>
#       <td id="T_dd449_row21_col1" class="data row21 col1" >234</td>
#       <td id="T_dd449_row21_col2" class="data row21 col2" >AA</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_dd449_row22_col0" class="data row22 col0" >Marlene</td>
#       <td id="T_dd449_row22_col1" class="data row22 col1" >10</td>
#       <td id="T_dd449_row22_col2" class="data row22 col2" >A1</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_dd449_row23_col0" class="data row23 col0" >NNALWAGA</td>
#       <td id="T_dd449_row23_col1" class="data row23 col1" >411</td>
#       <td id="T_dd449_row23_col2" class="data row23 col2" >B3</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_dd449_row24_col0" class="data row24 col0" >PRINCE</td>
#       <td id="T_dd449_row24_col1" class="data row24 col1" >3</td>
#       <td id="T_dd449_row24_col2" class="data row24 col2" >A1</td>
#     </tr>
#     <tr>
#       <th id="T_dd449_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_dd449_r

# %%
df.groupby('USER')['AREA',]\
    .value_counts()\
    .unstack(level=1)\
    .plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='USER'>

# %%
ax = df.plot.bar(x='USER', y='PICKS', rot=0)

# %%
ax = s.plot.bar(x='USER', y='PICKS',stacked=True)

# %%
df.groupby(['USER', 'AREA']).size().unstack().plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='USER'>

# %%
df.set_index('USER', inplace=True)

#group data by product and display sales as line chart
df.groupby('AREA')['PICKS'].plot(legend=True)
# Out:
# AREA
# A1    AxesSubplot(0.125,0.11;0.775x0.77)
# AA    AxesSubplot(0.125,0.11;0.775x0.77)
# B3    AxesSubplot(0.125,0.11;0.775x0.77)
# G1    AxesSubplot(0.125,0.11;0.775x0.77)
# Name: PICKS, dtype: object

# %%
df
# Out:
#                  Date         NAME AREA  UNITS  PICKS Shift Column1  Column2
# USER
# ASHLEY     2022-04-14       Ashley   B3   3924    427   NaN     NaN      NaN
# BAWANY     2022-04-14       BAWANY   A1    641    221   NaN     NaN      NaN
# BSUMANGIL  2022-04-14    Benedicta   B3   2507    541   NaN     NaN      NaN
# DALDRIN    2022-04-14       Doucot   AA   3721    470   NaN     NaN      NaN
# Doucot     2022-04-14       Aldrin   B3   1332     18   NaN     NaN      NaN
# ...               ...          ...  ...    ...    ...   ...     ...      ...
# SBARRWM    2023-01-27      Stephen   AA    111     71   NaN     NaN      NaN
# SHAYNE     2023-01-27       Shayne   AA     37     18   NaN     NaN      NaN
# SSRITHARAN 2023-01-27    Sinthujan   A1    432     90   NaN     NaN      NaN
# SSRITHARAN 2023-01-27    sritharan   B3    299     46   NaN     NaN      NaN
# ESIVA      2023-01-27  Vimalawathy   B3   3886    984   NaN     NaN      NaN
#
# [2649 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2649 entries, ASHLEY to ESIVA
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2649 non-null   datetime64[ns]
#  1   NAME     2649 non-null   object
#  2   AREA     2649 non-null   object
#  3   UNITS    2649 non-null   int64
#  4   PICKS    2649 non-null   int64
#  5   Shift    936 non-null    object
#  6   Column1  1 non-null      object
#  7   Column2  0 non-null      float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 186.3+ KB

# %%
df['Month']=df['Date'].dt.month
df.head()
# Out:
#                 Date       NAME AREA  UNITS  PICKS Shift Column1  Column2  \
# USER
# ASHLEY    2022-04-14     Ashley   B3   3924    427   NaN     NaN      NaN
# BAWANY    2022-04-14     BAWANY   A1    641    221   NaN     NaN      NaN
# BSUMANGIL 2022-04-14  Benedicta   B3   2507    541   NaN     NaN      NaN
# DALDRIN   2022-04-14     Doucot   AA   3721    470   NaN     NaN      NaN
# Doucot    2022-04-14     Aldrin   B3   1332     18   NaN     NaN      NaN
#
#            Month
# USER
# ASHLEY         4
# BAWANY         4
# BSUMANGIL      4
# DALDRIN        4
# Doucot         4

# %%
grouped_by_month=df.groupby(by=['Month']).sum()[['PICKS']]
grouped_by_month
# Out:
#         PICKS
# Month
# 1      196984
# 4      146505
# 5      311819
# 6      209359
# 7       86284
# 8      151557

# %%
bar_chart_by_month=(
    Bar()
    .add_xaxis(grouped_by_month.index.tolist())
    .add_yaxis('AREA',grouped_by_month['PICKS'].round(0).tolist())
    .set_global_opts(
            title_opts=opts.TitleOpts(title='PICKS',subtitle='---')
    )
)

# %%
bar_chart_by_month.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="18de981b77c0493680f7d4531b987636" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_18de981b77c0493680f7d4531b987636 = echarts.init(
#                     document.getElementById('18de981b77c0493680f7d4531b987636'), 'white', {renderer: 'canvas'});
#                 var option_18de981b77c0493680f7d4531b987636 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "AREA",
#             "legendHoverLink": true,
#             "data": [
#                 196984,
#                 146505,
#                 311819,
#                 209359,
#                 86284,
#                 151557
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "AREA"
#             ],
#             "selected": {
#                 "AREA": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 1,
#                 4,
#                 5,
#                 6,
#                 7,
#                 8
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "PICKS",
#             "target": "blank",
#             "subtext": "---",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_18de981b77c0493680f7d4531b987636.setOption(option_18de981b77c0493680f7d4531b987636);
#         });
#     </script>

# %%
group_by_sub_cat=df.groupby(by='AREA',as_index=False).sum().sort_values(by=['PICKS'])

# %%
group_by_sub_cat.head(5)
# Out:
#   AREA    UNITS   PICKS  Column2  Month
# 3   G1   124597   55104      0.0   1741
# 0   A1   553326  112478      0.0   2644
# 1   AA   688186  121836      0.0   1406
# 2   B3  2553469  813090      0.0   7493

# %%
bar_chart_by_sc=(
    Bar()
    .add_xaxis(group_by_sub_cat['AREA'].tolist())
    .add_yaxis('AREA',group_by_sub_cat['PICKS'].round(0).tolist())
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position='right'))
    .set_global_opts(
            title_opts=opts.TitleOpts(title='PICKS',subtitle='---')
    )
)

# %%
bar_chart_by_sc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8e051a1d97d241bba25ef41332fe4a5a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8e051a1d97d241bba25ef41332fe4a5a = echarts.init(
#                     document.getElementById('8e051a1d97d241bba25ef41332fe4a5a'), 'white', {renderer: 'canvas'});
#                 var option_8e051a1d97d241bba25ef41332fe4a5a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "AREA",
#             "legendHoverLink": true,
#             "data": [
#                 55104,
#                 112478,
#                 121836,
#                 813090
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "AREA"
#             ],
#             "selected": {
#                 "AREA": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "G1",
#                 "A1",
#                 "AA",
#                 "B3"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "PICKS",
#             "target": "blank",
#             "subtext": "---",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_8e051a1d97d241bba25ef41332fe4a5a.setOption(option_8e051a1d97d241bba25ef41332fe4a5a);
#         });
#     </script>

# %%
pick_by_day=df.groupby(by='Date').sum()[['PICKS']].round(0)
pick_by_day=pick_by_day.reset_index()
pick_by_day.head(5)
# Out:
#         Date  PICKS
# 0 2022-04-14  10028
# 1 2022-04-15  12537
# 2 2022-04-18   9732
# 3 2022-04-19  10825
# 4 2022-04-20  13078

# %%
data=pick_by_day [['Date','PICKS']].values.tolist()
data
# Out:
# [[Timestamp('2022-04-14 00:00:00'), 10028],
#  [Timestamp('2022-04-15 00:00:00'), 12537],
#  [Timestamp('2022-04-18 00:00:00'), 9732],
#  [Timestamp('2022-04-19 00:00:00'), 10825],
#  [Timestamp('2022-04-20 00:00:00'), 13078],
#  [Timestamp('2022-04-21 00:00:00'), 12610],
#  [Timestamp('2022-04-22 00:00:00'), 10110],
#  [Timestamp('2022-04-25 00:00:00'), 14301],
#  [Timestamp('2022-04-26 00:00:00'), 14378],
#  [Timestamp('2022-04-27 00:00:00'), 13140],
#  [Timestamp('2022-04-28 00:00:00'), 13723],
#  [Timestamp('2022-04-29 00:00:00'), 12043],
#  [Timestamp('2022-05-02 00:00:00'), 9659],
#  [Timestamp('2022-05-03 00:00:00'), 12621],
#  [Timestamp('2022-05-04 00:00:00'), 13465],
#  [Timestamp('2022-05-05 00:00:00'), 13121],
#  [Timestamp('2022-05-06 00:00:00'), 6156],
#  [Timestamp('2022-05-09 00:00:00'), 11408],
#  [Timestamp('2022-05-10 00:00:00'), 11830],
#  [Timestamp('2022-05-12 00:00:00'), 12504],
#  [Timestamp('2022-05-13 00:00:00'), 14084],
#  [Timestamp('2022-05-14 00:00:00'), 4815],
#  [Timestamp('2022-05-16 00:00:00'), 14779],
#  [Timestamp('2022-05-17 00:00:00'), 16353],
#  [Timestamp('2022-05-18 00:00:00'), 16703],
#  [Timestamp('2022-05-19 00:00:00'), 13403],
#  [Timestamp('2022-05-20 00:00:00'), 12545],
#  [Timestamp('2022-05-24 00:00:00'), 13905],
#  [Timestamp('2022-05-25 00:00:00'), 14809],
#  [Timestamp('2022-05-26 00:00:00'), 23932],
#  [Timestamp('2022-05-27 00:00:00'), 25583],
#  [Timestamp('2022-05-28 00:00:00'), 6208],
#  [Timestamp('2022-05-30 00:00:00'), 22076],
#  [Timestamp('2022-05-31 00:00:00'), 21860],
#  [Timestamp('2022-06-01 00:00:00'), 26413],
#  [Timestamp('2022-06-02 00:00:00'), 23975],
#  [Timestamp('2022-06-03 00:00:00'), 18918],
#  [Timestamp('2022-06-06 00:00:00'), 18889],
#  [Timestamp('2022-06-07 00:00:00'), 25113],
#  [Timestamp('2022-06-08 00:00:00'), 27487],
#  [Timestamp('2022-06-09 00:00:00'), 24153],
#  [Timestamp('2022-06-10 00:00:00'), 20006],
#  [Timestamp('2022-06-11 00:00:00'), 24405],
#  [Timestamp('2022-07-11 00:00:00'), 11175],
#  [Timestamp('2022-07-12 00:00:00'), 12157],
#  [Timestamp('2022-07-13 00:00:00'), 11857],
#  [Timestamp('2022-07-14 00:00:00'), 10075],
#  [Timestamp('2022-07-15 00:00:00'), 9280],
#  [Timestamp('2022-07-18 00:00:00'), 2],
#  [Timestamp('2022-07-19 00:00:00'), 10609],
#  [Timestamp('2022-07-20 00:00:00'), 10658],
#  [Timestamp('2022-07-21 00:00:00'), 10471],
#  [Timestamp('2022-08-11 00:00:00'), 14001],
#  [Timestamp('2022-08-12 00:00:00'), 10009],
#  [Timestamp('2022-08-15 00:00:00'), 10032],
#  [Timestamp('2022-08-16 00:00:00'), 12447],
#  [Timestamp('2022-08-17 00:00:00'), 13844],
#  [Timestamp('2022-08-18 00:00:00'), 10864],
#  [Timestamp('2022-08-22 00:00:00'), 13314],
#  [Timestamp('2022-08-23 00:00:00'), 10545],
#  [Timestamp('2022-08-24 00:00:00'), 11275],
#  [Timestamp('2022-08-25 00:00:00'), 10245],
#  [Timestamp('2022-08-29 00:00:00'), 11921],
#  [Timestamp('2022-08-30 00:00:00'), 11489],
#  [Timestamp('2022-08-31 00:00:00'), 11571],
#  [Timestamp('2023-01-03 00:00:00'), 10464],
#  [Timestamp('2023-01-04 00:00:00'), 12975],
#  [Timestamp('2023-01-05 00:00:00'), 12743],
#  [Timestamp('2023-01-06 00:00:00'), 11858],
#  [Timestamp('2023-01-09 00:00:00'), 8209],
#  [Timestamp('2023-01-10 00:00:00'), 13416],
#  [Timestamp('2023-01-11 00:00:00'), 12451],
#  [Timestamp('2023-01-12 00:00:00'), 10458],
#  [Timestamp('2023-01-13 00:00:00'), 11159],
#  [Timestamp('2023-01-16 00:00:00'), 12931],
#  [Timestamp('2023-01-17 00:00:00'), 10714],
#  [Timestamp('2023-01-18 00:00:00'), 9699],
#  [Timestamp('2023-01-19 00:00:00'), 7169],
#  [Timestamp('2023-01-23 00:00:00'), 11282],
#  [Timestamp('2023-01-24 00:00:00'), 12534],
#  [Timestamp('2023-01-25 00:00:00'), 11541],
#  [Timestamp('2023-01-26 00:00:00'), 10400],
#  [Timestamp('2023-01-27 00:00:00'), 6981]]

# %%
maxpick=df['PICKS'].max()
minpick=16000
maxpick
# Out:
# 1914

# %%
pick_cal=(
   Calendar()
    .add('', data, calendar_opts=opts.CalendarOpts(range_='2023'))
    .set_global_opts(
        title_opts=opts.TitleOpts(title='PICK Calendar', subtitle='LINES'),
        legend_opts=opts.LegendOpts(is_show=False),
        visualmap_opts=opts.VisualMapOpts(
                max_=maxpick,
                min_=minpick,
                orient='horizontal',
                is_piecewise=False,
                pos_top='230px',
                pos_left='100px',
        )
    )

)

# %%
pick_cal.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e8a3fe26969f459580158654e0b66835" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e8a3fe26969f459580158654e0b66835 = echarts.init(
#                     document.getElementById('e8a3fe26969f459580158654e0b66835'), 'white', {renderer: 'canvas'});
#                 var option_e8a3fe26969f459580158654e0b66835 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2022-04-14T00:00:00",
#                     10028
#                 ],
#                 [
#                     "2022-04-15T00:00:00",
#                     12537
#                 ],
#                 [
#                     "2022-04-18T00:00:00",
#                     9732
#                 ],
#                 [
#                     "2022-04-19T00:00:00",
#                     10825
#                 ],
#                 [
#                     "2022-04-20T00:00:00",
#                     13078
#                 ],
#                 [
#                     "2022-04-21T00:00:00",
#                     12610
#                 ],
#                 [
#                     "2022-04-22T00:00:00",
#                     10110
#                 ],
#                 [
#                     "2022-04-25T00:00:00",
#                     14301
#                 ],
#                 [
#                     "2022-04-26T00:00:00",
#                     14378
#                 ],
#                 [
#                     "2022-04-27T00:00:00",
#                     13140
#                 ],
#                 [
#                     "2022-04-28T00:00:00",
#                     13723
#                 ],
#                 [
#                     "2022-04-29T00:00:00",
#                     12043
#                 ],
#                 [
#                     "2022-05-02T00:00:00",
#                     9659
#                 ],
#                 [
#                     "2022-05-03T00:00:00",
#                     12621
#                 ],
#                 [
#                     "2022-05-04T00:00:00",
#                     13465
#                 ],
#                 [
#                     "2022-05-05T00:00:00",
#                     13121
#                 ],
#                 [
#                     "2022-05-06T00:00:00",
#                     6156
#                 ],
#                 [
#                     "2022-05-09T00:00:00",
#                     11408
#                 ],
#                 [
#                     "2022-05-10T00:00:00",
#                     11830
#                 ],
#                 [
#                     "2022-05-12T00:00:00",
#                     12504
#                 ],
#                 [
#                     "2022-05-13T00:00:00",
#                     14084
#                 ],
#                 [
#                     "2022-05-14T00:00:00",
#                     4815
#                 ],
#                 [
#                     "2022-05-16T00:00:00",
#                     14779
#                 ],
#                 [
#                     "2022-05-17T00:00:00",
#                     16353
#                 ],
#                 [
#                     "2022-05-18T00:00:00",
#                     16703
#                 ],
#                 [
#                     "2022-05-19T00:00:00",
#                     13403
#                 ],
#                 [
#                     "2022-05-20T00:00:00",
#                     12545
#                 ],
#                 [
#                     "2022-05-24T00:00:00",
#                     13905
#                 ],
#                 [
#                     "2022-05-25T00:00:00",
#                     14809
#                 ],
#                 [
#                     "2022-05-26T00:00:00",
#                     23932
#                 ],
#                 [
#                     "2022-05-27T00:00:00",
#                     25583
#                 ],
#                 [
#                     "2022-05-28T00:00:00",
#                     6208
#                 ],
#                 [
#                     "2022-05-30T00:00:00",
#                     22076
#                 ],
#                 [
#                     "2022-05-31T00:00:00",
#                     21860
#                 ],
#                 [
#                     "2022-06-01T00:00:00",
#                     26413
#                 ],
#                 [
#                     "2022-06-02T00:00:00",
#                     23975
#                 ],
#                 [
#                     "2022-06-03T00:00:00",
#                     18918
#                 ],
#                 [
#                     "2022-06-06T00:00:00",
#                     18889
#                 ],
#                 [
#                     "2022-06-07T00:00:00",
#                     25113
#                 ],
#                 [
#                     "2022-06-08T00:00:00",
#                     27487
#                 ],
#                 [
#                     "2022-06-09T00:00:00",
#                     24153
#                 ],
#                 [
#                     "2022-06-10T00:00:00",
#                     20006
#                 ],
#                 [
#                     "2022-06-11T00:00:00",
#                     24405
#                 ],
#                 [
#                     "2022-07-11T00:00:00",
#                     11175
#                 ],
#                 [
#                     "2022-07-12T00:00:00",
#                     12157
#                 ],
#                 [
#                     "2022-07-13T00:00:00",
#                     11857
#                 ],
#                 [
#                     "2022-07-14T00:00:00",
#                     10075
#                 ],
#                 [
#                     "2022-07-15T00:00:00",
#                     9280
#                 ],
#                 [
#                     "2022-07-18T00:00:00",
#                     2
#                 ],
#                 [
#                     "2022-07-19T00:00:00",
#                     10609
#                 ],
#                 [
#                     "2022-07-20T00:00:00",
#                     10658
#                 ],
#                 [
#                     "2022-07-21T00:00:00",
#                     10471
#                 ],
#                 [
#                     "2022-08-11T00:00:00",
#                     14001
#                 ],
#                 [
#                     "2022-08-12T00:00:00",
#                     10009
#                 ],
#                 [
#                     "2022-08-15T00:00:00",
#                     10032
#                 ],
#                 [
#                     "2022-08-16T00:00:00",
#                     12447
#                 ],
#                 [
#                     "2022-08-17T00:00:00",
#                     13844
#                 ],
#                 [
#                     "2022-08-18T00:00:00",
#                     10864
#                 ],
#                 [
#                     "2022-08-22T00:00:00",
#                     13314
#                 ],
#                 [
#                     "2022-08-23T00:00:00",
#                     10545
#                 ],
#                 [
#                     "2022-08-24T00:00:00",
#                     11275
#                 ],
#                 [
#                     "2022-08-25T00:00:00",
#                     10245
#                 ],
#                 [
#                     "2022-08-29T00:00:00",
#                     11921
#                 ],
#                 [
#                     "2022-08-30T00:00:00",
#                     11489
#                 ],
#                 [
#                     "2022-08-31T00:00

# %%
tab=Tab(page_title='test ')
tab.add(pick_cal,'pc')
tab.render(Path.cwd() / 'sa.html')
# Out:
# 'C:\\Users\\ysuyendran\\Desktop\\py\\sa.html'

# %%
stc=df.groupby(by=['USER','AREA']).sum()[['PICKS']]
stc
# Out:
#                 PICKS
# USER      AREA
# AASMAS    A1      270
#           B3    10055
# ADUGGAL   A1      267
#           B3     1803
# AFARAH    A1      634
# ...               ...
# WINKLETTE A1     4041
#           B3     5577
# YSUYEN    AA        2
#           B3     1797
# riley     B3        1
#
# [178 rows x 1 columns]

# %%
stcc=(
    Bar()
    .add_xaxis(stc.index.tolist())
    .add_yaxis('AREA',grouped_by_month['PICKS'].round(0).tolist())
    .set_global_opts(
            title_opts=opts.TitleOpts(title='PICKS',subtitle='---')
        
    
    )
)

# %%
stcc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="84498b0bdfd34926a713ce4ede190809" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_84498b0bdfd34926a713ce4ede190809 = echarts.init(
#                     document.getElementById('84498b0bdfd34926a713ce4ede190809'), 'white', {renderer: 'canvas'});
#                 var option_84498b0bdfd34926a713ce4ede190809 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "AREA",
#             "legendHoverLink": true,
#             "data": [
#                 196984,
#                 146505,
#                 311819,
#                 209359,
#                 86284,
#                 151557
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "AREA"
#             ],
#             "selected": {
#                 "AREA": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 [
#                     "AASMAS",
#                     "A1"
#                 ],
#                 [
#                     "AASMAS",
#                     "B3"
#                 ],
#                 [
#                     "ADUGGAL",
#                     "A1"
#                 ],
#                 [
#                     "ADUGGAL",
#                     "B3"
#                 ],
#                 [
#                     "AFARAH",
#                     "A1"
#                 ],
#                 [
#                     "AFARAH",
#                     "AA"
#                 ],
#                 [
#                     "AKANDASAMY",
#                     "B3"
#                 ],
#                 [
#                     "AKHAN",
#                     "G1"
#                 ],
#                 [
#                     "APRABHAHAR",
#                     "B3"
#                 ],
#                 [
#                     "APRABHAHAR",
#                     "G1"
#                 ],
#                 [
#                     "ASHLEY",
#                     "A1"
#                 ],
#                 [
#                     "ASHLEY",
#                     "B3"
#                 ],
#                 [
#                     "Ashley",
#                     "B3"
#                 ],
#                 [
#                     "BAWANY",
#                     "A1"
#                 ],
#                 [
#                     "BAWANY",
#                     "B3"
#                 ],
#                 [
#                     "BEERDUTTWM",
#                     "AA"
#                 ],
#                 [
#                     "BEERDUTTWM",
#                     "B3"
#                 ],
#                 [
#                     "BEERDUTTWM",
#                     "G1"
#                 ],
#                 [
#                     "BSUMANGIL",
#                     "B3"
#                 ],
#                 [
#                     "DALDRIN",
#                     "AA"
#                 ],
#                 [
#                     "DALDRIN",
#                     "B3"
#                 ],
#                 [
#                     "DALDRIN",
#                     "G1"
#                 ],
#                 [
#                     "DALWINDER1",
#                     "A1"
#                 ],
#                 [
#                     "DALWINDER1",
#                     "B3"
#                 ],
#                 [
#                     "DARYLWAVE",
#                     "B3"
#                 ],
#                 [
#                     "DBOODHOO",
#                     "G1"
#                 ],
#                 [
#                     "DGRANT",
#                     "A1"
#                 ],
#                 [
#                     "DGRANT",
#                     "B3"
#                 ],
#                 [
#                     "DHARMESH",
#                     "AA"
#                 ],
#                 [
#                     "DHUDGIN",
#                     "A1"
#                 ],
#                 [
#                     "DISIDROWM",
#                     "A1"
#                 ],
#                 [
#                     "DPERIYASA",
#                     "AA"
#                 ],
#                 [
#                     "DPERIYASA",
#                     "B3"
#                 ],
#                 [
#                     "DPERIYASA",
#                     "G1"
#                 ],
#                 [
#                     "DSANDRA",
#                     "A1"
#                 ],
#                 [
#                     "DSANDRA",
#                     "B3"
#                 ],
#                 [
#                     "Dhilan",
#                     "B3"
#                 ],
#                 [
#                     "Dhilan",
#                     "G1"
#                 ],
#                 [
#                     "Diana",
#                     "B3"
#                 ],
#                 [
#                     "Doucot",
#                     "A1"
#                 ],
#                 [
#                     "Doucot",
#                     "B3"
#                 ],
#                 [
#                     "Doucot",
#                     "G1"
#                 ],
#                 [
#                     "ECOFFEY",
#                     "G1"
#                 ],
#                 [
#                     "EDHILAN",

# %%
import matplotlib.pyplot as plt

area=df['AREA']
pick=df['PICKS']

plt.bar(area,pick)
df
# Out:
#                  Date         NAME AREA  UNITS  PICKS Shift Column1  Column2  \
# USER
# ASHLEY     2022-04-14       Ashley   B3   3924    427   NaN     NaN      NaN
# BAWANY     2022-04-14       BAWANY   A1    641    221   NaN     NaN      NaN
# BSUMANGIL  2022-04-14    Benedicta   B3   2507    541   NaN     NaN      NaN
# DALDRIN    2022-04-14       Doucot   AA   3721    470   NaN     NaN      NaN
# Doucot     2022-04-14       Aldrin   B3   1332     18   NaN     NaN      NaN
# ...               ...          ...  ...    ...    ...   ...     ...      ...
# SBARRWM    2023-01-27      Stephen   AA    111     71   NaN     NaN      NaN
# SHAYNE     2023-01-27       Shayne   AA     37     18   NaN     NaN      NaN
# SSRITHARAN 2023-01-27    Sinthujan   A1    432     90   NaN     NaN      NaN
# SSRITHARAN 2023-01-27    sritharan   B3    299     46   NaN     NaN      NaN
# ESIVA      2023-01-27  Vimalawathy   B3   3886    984   NaN     NaN      NaN
#
#             Month
# USER
# ASHLEY          4
# BAWANY          4
# BSUMANGIL       4
# DALDRIN         4
# Doucot          4
# ...           ...
# SBARRWM         1
# SHAYNE          1
# SSRITHARAN      1
# SSRITHARAN      1
# ESIVA           1
#
# [2649 rows x 9 columns]

# %%
pivoted = df.pivot_table(index='USER', columns="AREA", values="PICKS",margins_name='Total')
pivoted
df1=pivoted.tail(10).fillna('0').astype(int)
df1
# Out:
# AREA          A1  AA   B3  G1
# USER
# TGOMESWM       0   0    0   1
# TUSHY        399   0  532   0
# Tushyanthii    0   0  310   0
# USANTHAN       0   0  109   0
# VBERBER01      0   0    0   1
# VIMALA         0   0  913   0
# Vijaya       581   0  246   0
# WINKLETTE    367   0  464   0
# YSUYEN         0   2   49   0
# riley          0   0    1   0

# %%
import matplotlib.pyplot as plt
df1
a1=df1['A1']
aa=df1['AA']
b3=df1['B3']


plt.bar(aa,a1)
plt.bar(aa,b3)
# Out:
# <BarContainer object of 10 artists>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16156\4040096836.py in <module>
# ----> 1 ax = df.plot.bar(stacked=True)
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1129         other axis represents a measured value.
#    1130         """
# -> 1131         return self(kind="bar", x=x, y=y, **kwargs)
#    1132
#    1133     @Appender(
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     327         self._compute_plot_data()
#     328         self._setup_subplots()
# --> 329         self._make_plot()
#     330         self._add_table()
#     331         self._make_legend()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1539                 ax.set_title(label)
#    1540             elif self.stacked:
# -> 1541                 mask = y > 0
#    1542                 start = np.where(mask, pos_prior, neg_prior) + self._start_base
#    1543                 w = self.bar_width / 2
#
# TypeError: The DType <class 'numpy.dtype[datetime64]'> could not be promoted by <class 'numpy.dtype[int32]'>. This means that no common DType exists for the given inputs. For example they cannot be stored in a single array unless the dtype is `object`. The full list of DTypes is: (<class 'numpy.dtype[datetime64]'>, <class 'numpy.dtype[int32]'>)
